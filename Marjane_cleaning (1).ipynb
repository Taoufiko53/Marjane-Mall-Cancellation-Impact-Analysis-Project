# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Lenovo\Desktop\Marjane\Ref d’annulation 4.csv", encoding="ISO-8859-1", sep=";")
df1.head()
# Out:
#    id                                 name       DateLastUpdate
# 0   1     Annulation EMM- Rupture en stock  2023-10-09 13:42:31
# 1   2     Annulation EMM-Annulation client  2023-10-09 13:42:31
# 2   3  Annulation EMM-Article non conforme  2023-10-09 13:42:31
# 3   4                               Retour  2023-10-09 13:42:31
# 4   5   Annulation EMM-Préparation Bloquée  2023-10-09 13:42:31

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              41 non-null     int64
#  1   name            41 non-null     object
#  2   DateLastUpdate  41 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB

# %%
df1["DateLastUpdate"] = pd.to_datetime(df1["DateLastUpdate"], format="mixed", dayfirst=True, errors="coerce")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              41 non-null     int64
#  1   name            41 non-null     object
#  2   DateLastUpdate  41 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
print(df1.dtypes)
# Out:
# id                         int64
# name                      object
# DateLastUpdate    datetime64[ns]
# dtype: object

# %%
import psycopg2
import sqlalchemy

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:admin123.@localhost:5432/Marjane_db")

# %%
df1.rename(columns={"DateLastUpdate": "datelastupdate"}, inplace=True)

# %%
df1.head()
# Out:
#    id                                 name      datelastupdate
# 0   1     Annulation EMM- Rupture en stock 2023-10-09 13:42:31
# 1   2     Annulation EMM-Annulation client 2023-10-09 13:42:31
# 2   3  Annulation EMM-Article non conforme 2023-10-09 13:42:31
# 3   4                               Retour 2023-10-09 13:42:31
# 4   5   Annulation EMM-Préparation Bloquée 2023-10-09 13:42:31

# %%
df1.to_sql("annulation", engine, if_exists="append", index=False)
# Out:
# 41

# %%
df1["date_only"] = df1["datelastupdate"].dt.date

# %%
df1["date_only"] = pd.to_datetime(df1["date_only"], errors="coerce").dt.date

# %%
df1.info()

# %%
from sqlalchemy import Date

df1.to_sql(
    "annulation",
    engine,
    if_exists="replace",  
    index=False,
    dtype={"date_only": Date()}
)
# Out:
# 41

# %%
df1.isnull().sum()

# %%
 ############################# ORDER DETAIL EVENTS df

# %%
df2 = pd.read_csv(r"C:\Users\Lenovo\Desktop\Marjane\OrderDetailEvents 4.csv", sep=";")
df2.head()
# Out:
#      RECID  OrderLineId         Status                 date
# 0  3798893       925584       Accepted  2024-04-22 14:32:22
# 1  4675729       925584      Cancelled  2025-04-16 08:38:51
# 2  3798894       925584      Delivered  2024-04-25 11:00:59
# 3  3798895       925584  InPreparation  2024-04-24 15:58:23
# 4  3798896       925584        Shipped  2024-04-24 18:15:42

# %%
df2.columns= df2.columns.str.lower()

# %%
df2.head()

# %%
df2[df2.duplicated()]

# %%
df2["date"] = pd.to_datetime(df2["date"], errors="coerce").dt.date

# %%
df2.info()

# %%
df2.head()

# %%
df2.isnull().sum()

# %%
df2.rename(columns={"recid":"rec_id","orderlineid":"order_line_id"},inplace=True)

# %%
df2.head()
# Out:
#     rec_id  order_line_id         status        date
# 0  3798893         925584       Accepted  2024-04-22
# 1  4675729         925584      Cancelled  2025-04-16
# 2  3798894         925584      Delivered  2024-04-25
# 3  3798895         925584  InPreparation  2024-04-24
# 4  3798896         925584        Shipped  2024-04-24

# %%
####  recid  PRIMARY KEY
####  order_line_id  FOREIGN KEY

# %%
 ############################# ORDER DETAIL df

# %%
df3 = pd.read_csv(r"C:\Users\Lenovo\Desktop\Marjane\OrderDetail 4.csv", sep=";", encoding="ISO-8859-1")

df3.head()
# Out:
#         id orderLineId                 OrderId     status  quantity  \
# 0  1153777        9LV0  MARJMA2504152338ZRDYR1  Delivered         1
# 1  1153778        96MQ  MARJMA2504152338ZRDYR1  Delivered         1
# 2  1153779        9VXQ  MARJMA2504152338ZRDYR1  Delivered         1
# 3  1153784        29JV  MARJMA2504152338WRY0K9  Delivered         1
# 4  1153796        0L40  MARJMA2504152338QR7QPO  Delivered         1
#
#   offerPrice_UnitSalesPrice offerPrice_ShippingCost  \
# 0                     89,00                   15,00
# 1                     99,00                   15,00
# 2                     99,00                   15,00
# 3                    119,00                   15,00
# 4                    174,00                   15,00
#
#   sellingPrice_UnitSalesPrice sellingPrice_ShippingCost  \
# 0                       89,00                      8,00
# 1                       99,00                      8,00
# 2                       99,00                      8,00
# ...

# %%
df3.isnull().sum()
# Out:
# id                                 0
# orderLineId                        0
# OrderId                            0
# status                           362
# quantity                           0
# offerPrice_UnitSalesPrice          0
# offerPrice_ShippingCost            0
# sellingPrice_UnitSalesPrice        0
# sellingPrice_ShippingCost          0
# offer_Id                           0
# offer_supplyMode                 329
# offer_productId                    0
# offer_productTitle               362
# cancellation_reasonId          80794
# dtype: int64

# %%
df3.shape

# %%
df3= df3.drop(columns="cancellation_reasonId")

# %%
df3.isnull().sum()

# %%
df3[df3.duplicated()]

# %%
df3 = df3.dropna(subset=["status", "offer_supplyMode", "offer_productTitle"])

# %%
df3.isnull().sum()

# %%
df3

# %%
df3= df3.rename(columns={"OrderId": "order_id"})
df3
# Out:
#              id orderLineId                  order_id     status  quantity  \
# 0       1153777        9LV0    MARJMA2504152338ZRDYR1  Delivered         1
# 1       1153778        96MQ    MARJMA2504152338ZRDYR1  Delivered         1
# 2       1153779        9VXQ    MARJMA2504152338ZRDYR1  Delivered         1
# 3       1153784        29JV    MARJMA2504152338WRY0K9  Delivered         1
# 4       1153796        0L40    MARJMA2504152338QR7QPO  Delivered         1
# ...         ...         ...                       ...        ...       ...
# 113326   670063        WLP7    MARJMA2402151701RDJMDV  Cancelled         1
# 113327  1060439        WJ3R  MARJMA240122302131D29N24  Cancelled         1
# 113328  1318442        3RVY  MARJMA240122121231GR0NRE  Delivered         1
# 113329   924944        7LNP    MARJMA2312151500O7VDG7  Cancelled         1
# 113330   883425        GPYG  MARJMA230510133122QV3KVG  Cancelled         1
#
#        offerPrice_UnitSalesPrice offerPrice_ShippingCost  \
# ...

# %%
##########  id   PRIMARY KEY    
##########   order_id   FOREIGN KEY

# %%
########  OrderHeader   df

# %%
df4 = pd.read_csv(r"C:\Users\Lenovo\Desktop\Marjane\OrderHeader.csv", sep=";", encoding="ISO-8859-1")

# %%
df4.head()
# Out:
#                       OrderId  businessOrder salesChannel_Id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   salesChannel_Name  sellerId     status  customer_Reference  \
# 0     Marjane Maroc    164004  Cancelled               14167
# 1     Marjane Maroc    700425  Cancelled                5956
# 2     Marjane Maroc    700771  Cancelled              129601
# 3     Marjane Maroc    703183  Cancelled              154470
# 4     Marjane Maroc    700440  Cancelled               30748
#
#             purchasedAt                 updatedAt                 createdAt  \
# 0  2023-05-10T08:40:00Z  2025-02-06T12:48:16.972Z  2023-05-10T13:36:37.576Z
# ...

# %%
df4.isnull().sum()
# Out:
# OrderId                              0
# businessOrder                        0
# salesChannel_Id                      0
# salesChannel_Name                    0
# sellerId                             0
# status                               0
# customer_Reference                   0
# purchasedAt                          0
# updatedAt                            0
# createdAt                            0
# payment_Method                       0
# currencyCode                         0
# billingAddress_city                  0
# billingAddress_stateOrRegion    100000
# billingAddress_countryCode           0
# totalPrice_offerPrice                0
# totalPrice_sellingPrice              0
# dtype: int64

# %%
df4.shape
# Out:
# (100000, 16)

# %%
df4
# Out:
#                           OrderId  businessOrder salesChannel_Id  \
# 0        MARJMA230510133122QV3KVG          False          MARJMA
# 1          MARJMA2312151500O7VDG7          False          MARJMA
# 2          MARJMA2402151701RDJMDV          False          MARJMA
# 3      MARJMA24032122091122OEK51Z          False          MARJMA
# 4        MARJMA2403282001122R0L27          False          MARJMA
# ...                           ...            ...             ...
# 99995    MARJMA250411221237E3QYKY          False          MARJMA
# 99996    MARJMA250411221237P3J1K2          False          MARJMA
# 99997    MARJMA250411221237Q35W0R          False          MARJMA
# 99998    MARJMA250411221237R0LMKX          False          MARJMA
# 99999    MARJMA250411221237R3PV3Q          False          MARJMA
#
#       salesChannel_Name  sellerId     status  customer_Reference  \
# 0         Marjane Maroc    164004  Cancelled               14167
# ...

# %%
df4.columns = df4.columns.str.lower()
df4.head()
# Out:
#                       orderid  businessorder saleschannel_id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   saleschannel_name  sellerid     status  customer_reference  \
# 0     Marjane Maroc    164004  Cancelled               14167
# 1     Marjane Maroc    700425  Cancelled                5956
# 2     Marjane Maroc    700771  Cancelled              129601
# 3     Marjane Maroc    703183  Cancelled              154470
# 4     Marjane Maroc    700440  Cancelled               30748
#
#             purchasedat                 updatedat                 createdat  \
# 0  2023-05-10T08:40:00Z  2025-02-06T12:48:16.972Z  2023-05-10T13:36:37.576Z
# ...

# %%
df4["updatedat"] = df4["updatedat"].str.split("T").str[0]

# %%
df4.head()
# Out:
#                       orderid  businessorder saleschannel_id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   saleschannel_name  sellerid     status  customer_reference  \
# 0     Marjane Maroc    164004  Cancelled               14167
# 1     Marjane Maroc    700425  Cancelled                5956
# 2     Marjane Maroc    700771  Cancelled              129601
# 3     Marjane Maroc    703183  Cancelled              154470
# 4     Marjane Maroc    700440  Cancelled               30748
#
#             purchasedat   updatedat                 createdat  payment_method  \
# 0  2023-05-10T08:40:00Z  2025-02-06  2023-05-10T13:36:37.576Z            Card
# ...

# %%
df4["purchasedat"] = df4["purchasedat"].str.split("T").str[0]
df4["createdat"] = df4["createdat"].str.split("T").str[0]

# %%
df4.head()
# Out:
#                       orderid  businessorder saleschannel_id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   saleschannel_name  sellerid     status  customer_reference purchasedat  \
# 0     Marjane Maroc    164004  Cancelled               14167  2023-05-10
# 1     Marjane Maroc    700425  Cancelled                5956  2023-12-15
# 2     Marjane Maroc    700771  Cancelled              129601  2024-02-15
# 3     Marjane Maroc    703183  Cancelled              154470  2024-03-26
# 4     Marjane Maroc    700440  Cancelled               30748  2024-03-28
#
#     updatedat   createdat  payment_method currencycode billingaddress_city  \
# 0  2025-02-06  2023-05-10            Card          MAD          CASABLANCA
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   orderid                     100000 non-null  object
#  1   businessorder               100000 non-null  bool
#  2   saleschannel_id             100000 non-null  object
#  3   saleschannel_name           100000 non-null  object
#  4   sellerid                    100000 non-null  int64
#  5   status                      100000 non-null  object
#  6   customer_reference          100000 non-null  int64
#  7   purchasedat                 100000 non-null  object
#  8   updatedat                   100000 non-null  object
#  9   createdat                   100000 non-null  object
#  10  payment_method              100000 non-null  object
#  11  currencycode                100000 non-null  object
#  12  billingaddress_city         100000 non-null  object
# ...

# %%
for x in ["totalprice_offerprice","totalprice_sellingprice"]:
    df4[x]= df4[x].str.replace(",",".").astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 for x in ["totalprice_offerprice","totalprice_sellingprice"]:
# ----> 2     df4[x]= df4[x].str.replace(",",".").astype(float)
#       3 df4.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   orderid                     100000 non-null  object
#  1   businessorder               100000 non-null  bool
#  2   saleschannel_id             100000 non-null  object
#  3   saleschannel_name           100000 non-null  object
#  4   sellerid                    100000 non-null  int64
#  5   status                      100000 non-null  object
#  6   customer_reference          100000 non-null  int64
#  7   purchasedat                 100000 non-null  object
#  8   updatedat                   100000 non-null  object
#  9   createdat                   100000 non-null  object
#  10  payment_method              100000 non-null  object
#  11  currencycode                100000 non-null  object
#  12  billingaddress_city         100000 non-null  object
# ...

# %%
df4["currencycode"].unique()
# Out:
# array(['MAD'], dtype=object)

# %%
df4["billingaddress_countrycode"].unique()
# Out:
# array(['MA'], dtype=object)

# %%
df4.drop(columns=["currencycode","billingaddress_countrycode"], inplace=True )

# %%
df4.head()
# Out:
#                       orderid  businessorder saleschannel_id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   saleschannel_name  sellerid     status  customer_reference purchasedat  \
# 0     Marjane Maroc    164004  Cancelled               14167  2023-05-10
# 1     Marjane Maroc    700425  Cancelled                5956  2023-12-15
# 2     Marjane Maroc    700771  Cancelled              129601  2024-02-15
# 3     Marjane Maroc    703183  Cancelled              154470  2024-03-26
# 4     Marjane Maroc    700440  Cancelled               30748  2024-03-28
#
#     updatedat   createdat  payment_method billingaddress_city  \
# 0  2025-02-06  2023-05-10            Card          CASABLANCA
# ...

# %%
df4.isnull().sum()
# Out:
# orderid                    0
# businessorder              0
# saleschannel_id            0
# saleschannel_name          0
# sellerid                   0
# status                     0
# customer_reference         0
# purchasedat                0
# updatedat                  0
# createdat                  0
# payment_method             0
# billingaddress_city        0
# totalprice_offerprice      0
# totalprice_sellingprice    0
# dtype: int64

# %%
for col in ["purchasedat","updatedat","createdat"]:
    df4[col]= pd.to_datetime(df4[col]).dt.date

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   orderid                  100000 non-null  object
#  1   businessorder            100000 non-null  bool
#  2   saleschannel_id          100000 non-null  object
#  3   saleschannel_name        100000 non-null  object
#  4   sellerid                 100000 non-null  int64
#  5   status                   100000 non-null  object
#  6   customer_reference       100000 non-null  int64
#  7   purchasedat              100000 non-null  object
#  8   updatedat                100000 non-null  object
#  9   createdat                100000 non-null  object
#  10  payment_method           100000 non-null  object
#  11  billingaddress_city      100000 non-null  object
#  12  totalprice_offerprice    100000 non-null  float64
# ...

# %%
print(df4[["purchasedat", "updatedat", "createdat"]].head())
print(df4[["purchasedat", "updatedat", "createdat"]].dtypes)
# Out:
#   purchasedat   updatedat   createdat
# 0  2023-05-10  2025-02-06  2023-05-10
# 1  2023-12-15  2025-02-06  2023-12-15
# 2  2024-02-15  2024-11-23  2024-02-15
# 3  2024-03-26  2025-05-01  2024-03-26
# 4  2024-03-28  2025-04-26  2024-03-28
# purchasedat    object
# updatedat      object
# createdat      object
# dtype: object

# %%
df4 = df4.rename(columns={"orderid":"order_id","sellerid":"seller_id","purchasedat":"purchase_date","updatedat":"update_date","createdat":"create_date"})

# %%
df4.head()
# Out:
#                      order_id  businessorder saleschannel_id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   saleschannel_name  seller_id     status  customer_reference purchase_date  \
# 0     Marjane Maroc     164004  Cancelled               14167    2023-05-10
# 1     Marjane Maroc     700425  Cancelled                5956    2023-12-15
# 2     Marjane Maroc     700771  Cancelled              129601    2024-02-15
# 3     Marjane Maroc     703183  Cancelled              154470    2024-03-26
# 4     Marjane Maroc     700440  Cancelled               30748    2024-03-28
#
#   update_date create_date  payment_method billingaddress_city  \
# 0  2025-02-06  2023-05-10            Card          CASABLANCA
# ...

# %%
df4.loc[df4["billingaddress_city"].str.contains("CASA"), "billingaddress_city"] = "CASABLANCA"

# %%
df4.head()
# Out:
#                      order_id  businessorder saleschannel_id  \
# 0    MARJMA230510133122QV3KVG          False          MARJMA
# 1      MARJMA2312151500O7VDG7          False          MARJMA
# 2      MARJMA2402151701RDJMDV          False          MARJMA
# 3  MARJMA24032122091122OEK51Z          False          MARJMA
# 4    MARJMA2403282001122R0L27          False          MARJMA
#
#   saleschannel_name  seller_id     status  customer_reference purchase_date  \
# 0     Marjane Maroc     164004  Cancelled               14167    2023-05-10
# 1     Marjane Maroc     700425  Cancelled                5956    2023-12-15
# 2     Marjane Maroc     700771  Cancelled              129601    2024-02-15
# 3     Marjane Maroc     703183  Cancelled              154470    2024-03-26
# 4     Marjane Maroc     700440  Cancelled               30748    2024-03-28
#
#   update_date create_date  payment_method billingaddress_city  \
# 0  2025-02-06  2023-05-10            Card          CASABLANCA
# ...

# %%
df4["saleschannel_id"].unique()
df4["saleschannel_name"].unique()
# Out:
# array(['Marjane Maroc'], dtype=object)

# %%
df4.drop(columns=["saleschannel_id","saleschannel_name"], inplace=True )

# %%
df4.head()
# Out:
#                      order_id  businessorder  seller_id     status  \
# 0    MARJMA230510133122QV3KVG          False     164004  Cancelled
# 1      MARJMA2312151500O7VDG7          False     700425  Cancelled
# 2      MARJMA2402151701RDJMDV          False     700771  Cancelled
# 3  MARJMA24032122091122OEK51Z          False     703183  Cancelled
# 4    MARJMA2403282001122R0L27          False     700440  Cancelled
#
#    customer_reference purchase_date update_date create_date  payment_method  \
# 0               14167    2023-05-10  2025-02-06  2023-05-10            Card
# 1                5956    2023-12-15  2025-02-06  2023-12-15  CashOnDelivery
# 2              129601    2024-02-15  2024-11-23  2024-02-15  CashOnDelivery
# 3              154470    2024-03-26  2025-05-01  2024-03-26  CashOnDelivery
# 4               30748    2024-03-28  2025-04-26  2024-03-28            Card
#
#   billingaddress_city  totalprice_offerprice  totalprice_sellingprice
# ...

# %%
####### order_id  PRIMARY KEY

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112969 entries, 0 to 113330
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           112969 non-null  int64
#  1   orderLineId                  112969 non-null  object
#  2   order_id                     112969 non-null  object
#  3   status                       112969 non-null  object
#  4   quantity                     112969 non-null  int64
#  5   offerPrice_UnitSalesPrice    112969 non-null  object
#  6   offerPrice_ShippingCost      112969 non-null  object
#  7   sellingPrice_UnitSalesPrice  112969 non-null  object
#  8   sellingPrice_ShippingCost    112969 non-null  object
#  9   offer_Id                     112969 non-null  object
#  10  offer_supplyMode             112969 non-null  object
#  11  offer_productId              112969 non-null  object
# ...

# %%
df3.head()
# Out:
#         id orderLineId                order_id     status  quantity  \
# 0  1153777        9LV0  MARJMA2504152338ZRDYR1  Delivered         1
# 1  1153778        96MQ  MARJMA2504152338ZRDYR1  Delivered         1
# 2  1153779        9VXQ  MARJMA2504152338ZRDYR1  Delivered         1
# 3  1153784        29JV  MARJMA2504152338WRY0K9  Delivered         1
# 4  1153796        0L40  MARJMA2504152338QR7QPO  Delivered         1
#
#   offerPrice_UnitSalesPrice offerPrice_ShippingCost  \
# 0                     89,00                   15,00
# 1                     99,00                   15,00
# 2                     99,00                   15,00
# 3                    119,00                   15,00
# 4                    174,00                   15,00
#
#   sellingPrice_UnitSalesPrice sellingPrice_ShippingCost  \
# 0                       89,00                      8,00
# 1                       99,00                      8,00
# 2                       99,00                      8,00
# ...

# %%
for x in ["offerPrice_UnitSalesPrice","offerPrice_ShippingCost","sellingPrice_UnitSalesPrice","sellingPrice_ShippingCost"]:
    df3[x]= df3[x].str.replace(",",".").astype(float)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112969 entries, 0 to 113330
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           112969 non-null  int64
#  1   orderLineId                  112969 non-null  object
#  2   order_id                     112969 non-null  object
#  3   status                       112969 non-null  object
#  4   quantity                     112969 non-null  int64
#  5   offerPrice_UnitSalesPrice    112969 non-null  float64
#  6   offerPrice_ShippingCost      112969 non-null  float64
#  7   sellingPrice_UnitSalesPrice  112969 non-null  float64
#  8   sellingPrice_ShippingCost    112969 non-null  float64
#  9   offer_Id                     112969 non-null  object
#  10  offer_supplyMode             112969 non-null  object
#  11  offer_productId              112969 non-null  object
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   order_id                 100000 non-null  object
#  1   businessorder            100000 non-null  bool
#  2   seller_id                100000 non-null  int64
#  3   status                   100000 non-null  object
#  4   customer_reference       100000 non-null  int64
#  5   purchase_date            100000 non-null  object
#  6   update_date              100000 non-null  object
#  7   create_date              100000 non-null  object
#  8   payment_method           100000 non-null  object
#  9   billingaddress_city      100000 non-null  object
#  10  totalprice_offerprice    100000 non-null  float64
#  11  totalprice_sellingprice  100000 non-null  float64
# dtypes: bool(1), float64(2), int64(2), object(7)
# memory usage: 8.5+ MB

# %%
df4.columns
# Out:
# Index(['order_id', 'businessorder', 'seller_id', 'status',
#        'customer_reference', 'purchase_date', 'update_date', 'create_date',
#        'payment_method', 'billingaddress_city', 'totalprice_offerprice',
#        'totalprice_sellingprice'],
#       dtype='object')

# %%
df4.to_sql("order_header", engine, if_exists="append", index=False)
# Out:
# 1000

# %%
df3.head()
# Out:
#         id order_line_id                order_id     status  quantity  \
# 0  1153777          9LV0  MARJMA2504152338ZRDYR1  Delivered         1
# 1  1153778          96MQ  MARJMA2504152338ZRDYR1  Delivered         1
# 2  1153779          9VXQ  MARJMA2504152338ZRDYR1  Delivered         1
# 3  1153784          29JV  MARJMA2504152338WRY0K9  Delivered         1
# 4  1153796          0L40  MARJMA2504152338QR7QPO  Delivered         1
#
#    offerPrice_UnitSalesPrice  offerPrice_ShippingCost  \
# 0                       89.0                     15.0
# 1                       99.0                     15.0
# 2                       99.0                     15.0
# 3                      119.0                     15.0
# 4                      174.0                     15.0
#
#    sellingPrice_UnitSalesPrice  sellingPrice_ShippingCost  \
# 0                         89.0                        8.0
# 1                         99.0                        8.0
# ...

# %%
df3 = df3.rename(columns={
    "offerPrice_UnitSalesPrice": "offerPrice_UnitSalesPrice",
    "offerPrice_ShippingCost": "offerPrice_ShippingCost",
    "sellingPrice_UnitSalesPrice": "sellingPrice_UnitSalesPrice",
    "sellingPrice_ShippingCost": "sellingPrice_ShippingCost",
    "offer_Id": "offer_Id",
    "offer_supplyMode": "offer_supplyMode",
    "offer_productId": "offer_productId",
    "offer_productTitle": "offer_productTitle"
})
df3
# Out:
#              id order_line_id                  order_id     status  quantity  \
# 0       1153777          9LV0    MARJMA2504152338ZRDYR1  Delivered         1
# 1       1153778          96MQ    MARJMA2504152338ZRDYR1  Delivered         1
# 2       1153779          9VXQ    MARJMA2504152338ZRDYR1  Delivered         1
# 3       1153784          29JV    MARJMA2504152338WRY0K9  Delivered         1
# 4       1153796          0L40    MARJMA2504152338QR7QPO  Delivered         1
# ...         ...           ...                       ...        ...       ...
# 113326   670063          WLP7    MARJMA2402151701RDJMDV  Cancelled         1
# 113327  1060439          WJ3R  MARJMA240122302131D29N24  Cancelled         1
# 113328  1318442          3RVY  MARJMA240122121231GR0NRE  Delivered         1
# 113329   924944          7LNP    MARJMA2312151500O7VDG7  Cancelled         1
# 113330   883425          GPYG  MARJMA230510133122QV3KVG  Cancelled         1
#
# ...

# %%
df3 = df3.rename(columns={
    "offerPrice_UnitSalesPrice": "offerprice_unitsalesprice",
    "offerPrice_ShippingCost": "offerprice_shippingcost",
    "sellingPrice_UnitSalesPrice": "sellingprice_unitsalesprice",
    "sellingPrice_ShippingCost": "sellingprice_shippingcost",
    "offer_Id": "offer_id",
    "offer_supplyMode": "offer_supplymode",
    "offer_productId": "offer_productid",
    "offer_productTitle": "offer_producttitle"
})

# %%
df3 = df3.rename(columns={
    "orderLineId": "order_line_id",
    "offerPrice_UnitSalesPrice": "offerPrice_UnitSalesPrice",
    "offerPrice_ShippingCost": "offerPrice_ShippingCost",
    "sellingPrice_UnitSalesPrice": "sellingPrice_UnitSalesPrice",
    "sellingPrice_ShippingCost": "sellingPrice_ShippingCost",
    "offer_Id": "offer_Id",
    "offer_supplyMode": "offer_supplyMode",
    "offer_productId": "offer_productId",
    "offer_productTitle": "offer_productTitle"
})

# %%
df3.head()
# Out:
#         id order_line_id                order_id     status  quantity  \
# 0  1153777          9LV0  MARJMA2504152338ZRDYR1  Delivered         1
# 1  1153778          96MQ  MARJMA2504152338ZRDYR1  Delivered         1
# 2  1153779          9VXQ  MARJMA2504152338ZRDYR1  Delivered         1
# 3  1153784          29JV  MARJMA2504152338WRY0K9  Delivered         1
# 4  1153796          0L40  MARJMA2504152338QR7QPO  Delivered         1
#
#    offerprice_unitsalesprice  offerprice_shippingcost  \
# 0                       89.0                     15.0
# 1                       99.0                     15.0
# 2                       99.0                     15.0
# 3                      119.0                     15.0
# 4                      174.0                     15.0
#
#    sellingprice_unitsalesprice  sellingprice_shippingcost  \
# 0                         89.0                        8.0
# 1                         99.0                        8.0
# ...

# %%
df3.columns
# Out:
# Index(['id', 'order_line_id', 'order_id', 'status', 'quantity',
#        'offerprice_unitsalesprice', 'offerprice_shippingcost',
#        'sellingprice_unitsalesprice', 'sellingprice_shippingcost', 'offer_id',
#        'offer_supplymode', 'offer_productid', 'offer_producttitle'],
#       dtype='object')

# %%
df3.to_sql("order_detail", engine, if_exists="append", index=False)
# Out:
# 969

# %%
df2.columns
# Out:
# Index(['rec_id', 'order_line_id', 'status', 'date'], dtype='object')

# %%
df2.to_sql("order_detail_events", engine, if_exists="append", index=False)
# Out:
# 63

# %%
df1.to_csv("annulation.csv", index=False, encoding="utf-8-sig")
